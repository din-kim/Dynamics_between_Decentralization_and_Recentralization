# %%
# Import Classes
import random
from Reality import *
from Organization import *
from User import *
from functions import *

# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
np.set_printoptions(4)
random.seed(11)

# %%
"""
Variables
- m : number of attributes
- n : number of users
- p : participation rate
- k : degree of interdependence
- t : total number of tokens
- dr: distribution rate of tokens
"""

rds = 10
v = 10
m = 100
n = 100
k = 5
t = 100000
dr = 1
tokens = list(distribute_tokens(n, t, dr))
ids = list(range(n))

# %%
# Initiate Reality and Organization
reality = Reality(m)
organization = Organization(m, reality)

# Initiate Users
users = []
for i in range(n):
    globals()['user{}'.format(i)] = User(m, k, organization, ids, tokens)
    users.append(globals()['user{}'.format(i)])

# %%
vots = []
deles = []
vot_anys = []
p_ys =[]
p_ns = []
knws = []
prfs = []

# Initiate Vote
for rd in range(rds):
    vote_list = generate_vote_list(m, v)
    vot, dele, vot_any, p_y, p_n, knw, prf = vote_handler(reality, organization, users, vote_list)
    vots.append(vot)
    deles.append(dele)
    vot_anys.append(vot_any)
    p_ys.append(p_y)
    p_ns.append(p_n)
    knws.append(knw)
    prfs.append(prf)
# Out:
# ****************************************
# VOTE TARGET: [58, 25, 65, 80, 22, 32, 10, 95, 82, 13]
# ****************************************
#
#
# ...
# INITIATING A VOTE ON ATTR#58(0)
# ...
#
# >>>>>>>>>>>>>>>>
# user#0 initiates voting.
# USER -O- MATCH -O- ORGANIZATION
# Vote success!
# ----------------
#
# user#1 initiates voting.
# USER -X- UNMATCH -X- ORGANIZATION
# = user#1 is searching 70 users.
# == Start Searching!
# == Search Succeed: Start Delegating!
# user#1 delegated 821.6817410777977 tokens to user#32
# Vote success!
# ----------------
#
# user#2 initiates voting.
# USER -O- MATCH -O- ORGANIZATION
# Vote success!
# ----------------
#
# user#3 initiates voting.
# USER -X- UNMATCH -X- ORGANIZATION
# = user#3 is searching 36 users.
# == Start Searching!
# == Search Failed: user#3's knowledge is higher than other users' AOD.
# Start Voting Anyway!
# Vote success!
# ----------------
#
# user#4 initiates voting.
# Did not exercise the voting right!
# ----------------
#
# ...

# %%
plot_vote_category_cnts(vots,deles,vot_anys)

# %%
plot_participation(p_ys)

# %%
plot_knowledge_performance(knws, prfs)
